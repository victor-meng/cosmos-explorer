# %% [markdown]
# # Markdown linked image
#
# ![This image is linked](https://opspublicscus.blob.core.windows.net/test-content/A1.jpg)

# %% [markdown]
# # HTML image
#
# <img src="https://opspublicscus.blob.core.windows.net/test-content/A2.jpg" />

# %% [markdown]
# # Embed base64 image
#
# ![image](data:image/png;base64,...)

# %% [markdown]
# # Display image using code

# %%
from IPython.display import Image
Image("https://opspublicscus.blob.core.windows.net/test-content/B2.jpg")
